# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalrk1/DIP-Assignments/blob/main/DIP_Contrass_Imporvement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Downloading Image
# !wget https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import numpy as np

#read image
img1 = mpimg.imread('/content/Lenna_(test_image).png')

#Increased contrast
img2 = img1*2

#decreased contrast
img3 = img1/2

#subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(1,3) 
axarr[0].imshow(img1)
axarr[0].set_title('original image')
axarr[1].imshow(img2)
axarr[1].set_title('Increased contrast image')
axarr[2].imshow(img3)
axarr[2].set_title('decreased contrast image')
plt.show();
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
